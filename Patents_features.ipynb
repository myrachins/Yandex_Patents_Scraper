# %%
from IPython.display import clear_output
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm import tqdm
from os import walk
import numpy as np
import datetime
import time
import re

# %%
chromedriver_file_name = r'PATH TO chromedriver' # can be found here: https://chromedriver.chromium.org/
patents_directory = 'patents_2014-2016/'
features_json_style_file = 'data/features.txt'
broken_links_file_name = 'data/broken_links.txt'
features_file_name = 'data/features.csv'
yandex_patents_prefix = 'https://yandex.ru'

# %%
code_to_name = {'(21)(22)':'request',
                '(22)':'request_date',
                '(24)':'start_date',
                '(32)':'convention_priority',
                '(45)':'publish_date',
                '(72)':'authors',
                '(73)':'patent_holder',
                '(56)':'links'}

# %%
driver = webdriver.Chrome(chromedriver_file_name)

# %% [raw]
# patent_link = 'https://yandex.ru/patents/doc/RU2092489C1_19971010'

# %% [raw]
# driver.get(patent_link)

# %% [raw]
# driver.page_source

# %% [raw]
# soup = BeautifulSoup(driver.page_source)

# %% [raw]
# soup.find("div", {"class": "document-title document-title__desktop"}).contents[0].contents[0] # title

# %% [raw]
# soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['doc-url-item']).contents[0] # country

# %% [raw]
# soup.find("div", {"class": "doc-url-item doc-url-number"}).contents[0] # document_number

# %% [raw]
# soup.find("div", {"class": "doc-url-item center-content"}).contents[0] # document_type_code

# %% [raw]
# soup.find("div", {"class": "header-mpk-item header-mpk-title-item"}).contents[0] # mpk_1

# %% [raw]
# [tag.contents[0] for tag in soup.find_all(lambda tag: tag.name == 'div' and tag.get('class') == ['header-mpk-item'])] # mpk_2

# %% [raw]
# [tag.contents[0] for tag in soup.find_all("span", {"class": "header-mpk-sub-item"})] # mpk_3

# %%
def parse_bottom_links(soup, doc_id):
    links = soup.find("div", {"id":doc_id})
    if links is None:
        return None
    docs =  (links
                .find_next('div')
                .find_all("div", {"class":"doctable_row doctable_row_click"}))
    result = []
    for doc in docs:
        cells = [cell.contents[0] for cell in doc.find_all("span", {"class":"doctable_cell"})]
        result.append(cells)
    return result

# %% [raw]
# parse_bottom_links(soup, "doc-table-cited-by")

# %% [raw]
# parse_bottom_links(soup, "doc-table-citation")

# %% [raw]
# left_part = soup.find("div", {"class": "left-part left-part__desktop"})
# right_part = soup.find("div", {"class": "right-part right-part__desktop"})

# %%
def prettify(content):
    pretty = {}
    prettify_string = (lambda value: value.strip() if '<br/>' not in value
                                    else value.strip().split('<br/>'))
    
    for key, value in content.items():
        new_value = value
        if type(value) is list:
            new_value = list(map(prettify_string, new_value))
        else:
            new_value = prettify_string(new_value)
        pretty[code_to_name[key]] = new_value
    
    return pretty

# %%
def value_for_2122(item):
    elements = item.find_all("div", {"class": "header-content-item"})
    if len(elements) == 1: # href
        return elements[0].contents[0].find('span').contents[0]
    
    return elements[1].contents[0]

# %%
def value_for_56(item):
    tag_links = item.find("div", {"class": "right-part__citations"}).contents
    result = []
    for tag_link in tag_links:
        if not hasattr(tag_link.contents[0], 'contents'):
            result.append(tag_link.contents[0])
        else:
            result.append(tag_link.contents[0].contents[0].contents[0])
    
    return result

# %%
def parse_horizontal_part(part):
    content = {}
    
    for item in part.find_all("div", {"class": "header-item-part"}):
        header = item.find("div", {"class": "header-sup-item"}).contents[0]
        value = None
        
        if header == '(21)(22)':
            value = value_for_2122(item)
        elif header == '(56)':
            value = value_for_56(item)
        else:
            contents = item.find(re.compile("(div|span)"), {"class": "header-content-item"}).contents
            value = ''.join(map(str, contents))
            
        content[header] = value
        
    return prettify(content)

# %% [raw]
# left_part.find_all("div", {"class": "header-content-item"})[0].contents[0].find('span').contents[0]

# %% [raw]
# parse_horizontal_part(left_part)

# %% [raw]
# parse_horizontal_part(right_part)

# %% [raw]
# (right_part.find_all("div", {"class": "header-item-part"})[2]
#  .find("div", {"class": "right-part__citations"})
#  .contents[3].contents[0].contents[0].contents[0])

# %% [raw]
# right_part.find_all("div", {"class": "header-item-part"})[2].find("div", {"class": "right-part__citations"}).contents[2].contents

# %%
def parse_head_part(soup):
    content = {}
    
    content['title'] = soup.find("div", {"class": "document-title document-title__desktop"}).contents[0].contents[0]
    content['country'] = soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['doc-url-item']).contents[0]
    content['document_number'] = soup.find("div", {"class": "doc-url-item doc-url-number"}).contents[0]
    content['document_type_code'] = soup.find("div", {"class": "doc-url-item center-content"}).contents[0]
    content['mpk_1'] = soup.find("div", {"class": "header-mpk-item header-mpk-title-item"}).contents[0]
    content['mpk_2'] = [tag.contents[0] for tag in soup.find_all(lambda tag: tag.name == 'div'
                                                                 and tag.get('class') == ['header-mpk-item'])]
    #content['mpk_2'] = soup.find(lambda tag: tag.name == 'div' and tag.get('class') == ['header-mpk-item']).contents[0]
    #content['mpk_3'] = soup.find("span", {"class": "header-mpk-sub-item"}).contents[0]
    content['mpk_3'] = [tag.contents[0] for tag in soup.find_all("span", {"class": "header-mpk-sub-item"})]
    
    return content

# %%
def parse_yandex_links(soup):
    content = {}
    
    content['yandex_cited_by'] = parse_bottom_links(soup, "doc-table-cited-by")
    content['yandex_citations'] = parse_bottom_links(soup, "doc-table-citation")
    
    return content

# %%
def create_json(page_html):
    soup = BeautifulSoup(page_html)
    head_json = parse_head_part(soup)
    
    left_part = soup.find("div", {"class": "left-part left-part__desktop"})
    right_part = soup.find("div", {"class": "right-part right-part__desktop"})
    left_json = parse_horizontal_part(left_part)
    right_json = parse_horizontal_part(right_part)
    
    yandex_links = parse_yandex_links(soup)
    
    return {**head_json, **left_json, **right_json, **yandex_links}

# %% [raw]
# create_json(driver.page_source)

# %%
_, _, year_files = next(walk(patents_directory))

# %%
def save_json_line(json, year_file):
    year = year_file.split('.')[0]
    split = features_json_style_file.split('.')
    file, ext = ''.join(split[:-1]), split[-1]
    with open(file + '_' + year + '.' + ext, 'a') as f:
        f.write(str(json))
        f.write('\n')

# %%
def save_broken_link(link):
    with open(broken_links_file_name, 'a') as f:
        f.write(link)
        f.write('\n')

# %%
def get_links(file_name):
    with open(file_name, 'r') as f:
        return [yandex_patents_prefix + line.strip().replace('"', '') for line in f]

# %%
def parse_html(driver, patent_link):
    driver.get(patent_link)
    time.sleep(np.random.rand() * 0.5 + 1.2)

# %%
for year_file in year_files:
    patent_links = get_links(patents_directory + year_file)
    print('Parsing for', year_file)
    for i, patent_link in enumerate(patent_links):
        try:
            html = parse_html(driver, patent_link)
            json = create_json(driver.page_source)
            json['link'] = patent_link
            save_json_line(json, year_file)
            print('+ Link parsed', patent_link, '|', f'{i + 1} from {len(patent_links)}')
        except KeyboardInterrupt: raise
        except:
            print('For link', patent_link)
            save_broken_link(patent_link)
        if (i + 1) % 1000 == 0:
            clear_output(wait=True)
            print('Parsing for', year_file)
# Out:
# Parsing for 2016.txt
# + Link parsed https://yandex.ru/patents/doc/RU2639398C1_20171221 | 32001 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638460C1_20171213 | 32002 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175069U1_20171117 | 32003 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634815C1_20171103 | 32004 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634007C1_20171023 | 32005 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174368U1_20171011 | 32006 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173978U1_20170922 | 32007 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173863U1_20170915 | 32008 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173377U1_20170824 | 32009 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172972U1_20170802 | 32010 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172873U1_20170728 | 32011 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172647U1_20170718 | 32012 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171487U1_20170602 | 32013 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171423U1_20170531 | 32014 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170485U1_20170426 | 32015 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU169384U1_20170316 | 32016 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2711566C2_20200117 | 32017 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2700217C2_20190913 | 32018 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2671719C2_20181106 | 32019 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2665220C2_20180828 | 32020 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663767C2_20180809 | 32021 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663204C2_20180802 | 32022 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2662268C2_20180725 | 32023 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2661884C2_20180720 | 32024 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2660111C2_20180704 | 32025 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU180810U1_20180622 | 32026 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2652520C1_20180426 | 32027 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650000C1_20180406 | 32028 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648731C1_20180328 | 32029 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648178C1_20180322 | 32030 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645203C1_20180216 | 32031 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644217C1_20180208 | 32032 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644320C1_20180208 | 32033 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643684C1_20180205 | 32034 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643126C1_20180130 | 32035 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641604C1_20180118 | 32036 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175857U1_20171221 | 32037 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173791U1_20170911 | 32038 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173683U1_20170905 | 32039 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172327U1_20170704 | 32040 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171599U1_20170607 | 32041 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171432U1_20170531 | 32042 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170541U1_20170428 | 32043 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2701107C2_20190924 | 32044 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2687687C1_20190515 | 32045 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2684392C2_20190409 | 32046 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2676260C2_20181227 | 32047 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2676121C2_20181226 | 32048 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2671449C2_20181031 | 32049 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2668627C1_20181002 | 32050 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2666411C1_20180907 | 32051 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2661566C2_20180717 | 32052 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658550C1_20180621 | 32053 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2657787C1_20180615 | 32054 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU179920U1_20180529 | 32055 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2652300C1_20180425 | 32056 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651923C1_20180424 | 32057 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651704C1_20180423 | 32058 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651119C1_20180418 | 32059 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649840C1_20180404 | 32060 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649208C1_20180330 | 32061 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649221C1_20180330 | 32062 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649053C1_20180329 | 32063 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648017C1_20180321 | 32064 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646201C1_20180301 | 32065 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644643C1_20180213 | 32066 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU176636U1_20180124 | 32067 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641831C1_20180122 | 32068 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641205C1_20180116 | 32069 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639080C1_20171219 | 32070 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175321U1_20171130 | 32071 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175072U1_20171117 | 32072 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635445C1_20171113 | 32073 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174879U1_20171108 | 32074 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633975C1_20171020 | 32075 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633408C1_20171012 | 32076 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630294C1_20170906 | 32077 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173693U1_20170906 | 32078 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172301U1_20170704 | 32079 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171484U1_20170601 | 32080 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171358U1_20170529 | 32081 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170486U1_20170426 | 32082 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170487U1_20170426 | 32083 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170352U1_20170424 | 32084 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2691683C2_20190617 | 32085 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2685957C2_20190423 | 32086 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2683581C2_20190329 | 32087 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2667395C2_20180919 | 32088 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2664201C2_20180815 | 32089 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2661452C2_20180717 | 32090 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658707C1_20180622 | 32091 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656008C1_20180530 | 32092 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651679C1_20180423 | 32093 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177954U1_20180319 | 32094 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177685U1_20180306 | 32095 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177351U1_20180216 | 32096 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641568C1_20180118 | 32097 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641133C1_20180116 | 32098 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640059C1_20171226 | 32099 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637683C1_20171206 | 32100 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175273U1_20171129 | 32101 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634653C1_20171102 | 32102 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633186C1_20171011 | 32103 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2631057C1_20170918 | 32104 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630789C1_20170913 | 32105 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173806U1_20170912 | 32106 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173765U1_20170911 | 32107 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171823U1_20170616 | 32108 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171296U1_20170529 | 32109 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170409U1_20170424 | 32110 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2705014C1_20191101 | 32111 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2690169C2_20190531 | 32112 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2679055C2_20190205 | 32113 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU186750U1_20190131 | 32114 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2670310C2_20181022 | 32115 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2665713C2_20180904 | 32116 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2664745C2_20180822 | 32117 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2662638C2_20180726 | 32118 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2659130C1_20180628 | 32119 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2655675C1_20180529 | 32120 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648094C1_20180322 | 32121 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647710C1_20180319 | 32122 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647645C1_20180316 | 32123 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177752U1_20180312 | 32124 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645905C1_20180301 | 32125 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645687C1_20180227 | 32126 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644363C1_20180209 | 32127 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643375C1_20180201 | 32128 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637190C1_20171130 | 32129 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175183U1_20171124 | 32130 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174695U1_20171026 | 32131 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174098U1_20171002 | 32132 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173589U1_20170831 | 32133 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172999U1_20170803 | 32134 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172194U1_20170630 | 32135 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172037U1_20170626 | 32136 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171778U1_20170615 | 32137 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663172C2_20180801 | 32138 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU181982U1_20180731 | 32139 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2661738C2_20180719 | 32140 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658119C1_20180619 | 32141 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654346C1_20180517 | 32142 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2653091C1_20180507 | 32143 from 32489
# For link https://yandex.ru/patents/doc/RU2649801C1_20180404
# + Link parsed https://yandex.ru/patents/doc/RU2649352C1_20180402 | 32145 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648148C1_20180322 | 32146 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645952C1_20180228 | 32147 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641342C1_20180117 | 32148 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641120C1_20180116 | 32149 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640110C1_20171226 | 32150 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636512C1_20171123 | 32151 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635799C1_20171116 | 32152 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635204C1_20171109 | 32153 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634349C1_20171026 | 32154 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633313C1_20171011 | 32155 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174248U1_20171009 | 32156 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173038U1_20170808 | 32157 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172510U1_20170711 | 32158 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171398U1_20170530 | 32159 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171364U1_20170529 | 32160 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170944U1_20170516 | 32161 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170823U1_20170511 | 32162 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2705954C1_20191112 | 32163 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2672316C2_20181113 | 32164 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663094C2_20180801 | 32165 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2659179C1_20180628 | 32166 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2657317C1_20180613 | 32167 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656905C1_20180607 | 32168 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2653560C1_20180511 | 32169 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650820C1_20180417 | 32170 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649028C1_20180329 | 32171 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648839C1_20180328 | 32172 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648008C1_20180321 | 32173 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647794C1_20180319 | 32174 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646546C1_20180305 | 32175 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644715C1_20180213 | 32176 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643837C1_20180206 | 32177 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641340C1_20180117 | 32178 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640285C1_20171227 | 32179 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639721C1_20171222 | 32180 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174684U1_20171025 | 32181 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2631327C1_20170921 | 32182 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630927C1_20170914 | 32183 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630890C1_20170913 | 32184 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171769U1_20170615 | 32185 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171773U1_20170615 | 32186 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171383U1_20170530 | 32187 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171413U1_20170530 | 32188 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171174U1_20170523 | 32189 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2689090C2_20190523 | 32190 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2688729C1_20190522 | 32191 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU181983U1_20180731 | 32192 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2653933C1_20180515 | 32193 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651782C1_20180423 | 32194 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649878C1_20180405 | 32195 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647784C1_20180319 | 32196 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646955C1_20180312 | 32197 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646671C1_20180306 | 32198 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645878C1_20180228 | 32199 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177331U1_20180215 | 32200 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641140C1_20180116 | 32201 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640051C1_20171226 | 32202 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639410C1_20171221 | 32203 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175078U1_20171117 | 32204 from 32489
# For link https://yandex.ru/patents/doc/RU2633901C1_20171019
# + Link parsed https://yandex.ru/patents/doc/RU2630482C1_20170911 | 32206 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172552U1_20170712 | 32207 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172346U1_20170704 | 32208 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171795U1_20170616 | 32209 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171779U1_20170615 | 32210 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171185U1_20170523 | 32211 from 32489
# For link https://yandex.ru/patents/doc/RU2711939C2_20200123
# + Link parsed https://yandex.ru/patents/doc/RU2697036C1_20190808 | 32213 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2687243C1_20190508 | 32214 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2680889C2_20190228 | 32215 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654938C1_20180523 | 32216 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU179519U1_20180517 | 32217 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650814C1_20180417 | 32218 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647223C1_20180314 | 32219 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177206U1_20180213 | 32220 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641338C1_20180117 | 32221 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU176246U1_20180112 | 32222 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638847C1_20171218 | 32223 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638026C1_20171211 | 32224 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638027C1_20171211 | 32225 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175564U1_20171211 | 32226 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175591U1_20171211 | 32227 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637477C1_20171204 | 32228 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635227C1_20171109 | 32229 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634390C1_20171026 | 32230 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634276C1_20171024 | 32231 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174544U1_20171019 | 32232 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2632331C1_20171004 | 32233 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2632440C1_20171004 | 32234 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172275U1_20170703 | 32235 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171803U1_20170616 | 32236 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171075U1_20170518 | 32237 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170358U1_20170424 | 32238 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2705793C1_20191112 | 32239 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2695579C1_20190724 | 32240 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2684153C2_20190404 | 32241 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2671991C2_20181108 | 32242 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2669181C2_20181008 | 32243 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2667128C2_20180914 | 32244 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658138C1_20180619 | 32245 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2655599C1_20180528 | 32246 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2652683C1_20180428 | 32247 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647661C1_20180316 | 32248 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647109C1_20180313 | 32249 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640768C1_20180111 | 32250 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639321C1_20171221 | 32251 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175883U1_20171221 | 32252 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636740C1_20171128 | 32253 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636529C1_20171123 | 32254 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2632951C1_20171011 | 32255 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2632806C1_20171009 | 32256 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173430U1_20170828 | 32257 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171805U1_20170616 | 32258 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171730U1_20170613 | 32259 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171586U1_20170606 | 32260 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171150U1_20170522 | 32261 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2689448C1_20190528 | 32262 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU182737U1_20180829 | 32263 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2659798C1_20180704 | 32264 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656976C1_20180607 | 32265 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2655200C1_20180524 | 32266 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2653092C1_20180507 | 32267 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648355C1_20180323 | 32268 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645959C1_20180228 | 32269 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635799C9_20180216 | 32270 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645166C1_20180216 | 32271 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644893C1_20180214 | 32272 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2642805C1_20180126 | 32273 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174089U1_20171002 | 32274 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173112U1_20170814 | 32275 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173077U1_20170808 | 32276 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171521U1_20170605 | 32277 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170828U1_20170511 | 32278 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU169759U1_20170331 | 32279 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU186696U1_20190129 | 32280 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2676809C2_20190111 | 32281 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2674994C2_20181214 | 32282 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2673042C2_20181121 | 32283 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2671620C1_20181102 | 32284 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2666956C2_20180913 | 32285 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2664407C2_20180817 | 32286 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663342C2_20180803 | 32287 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2661344C2_20180716 | 32288 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658675C1_20180622 | 32289 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654662C1_20180521 | 32290 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650349C1_20180411 | 32291 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648465C1_20180326 | 32292 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU178092U1_20180322 | 32293 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646047C1_20180301 | 32294 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177367U1_20180219 | 32295 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644892C1_20180214 | 32296 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644934C1_20180214 | 32297 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644692C1_20180213 | 32298 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2642350C1_20180124 | 32299 from 32489
# For link https://yandex.ru/patents/doc/RU2642247C1_20180124
# + Link parsed https://yandex.ru/patents/doc/RU2641249C1_20180116 | 32301 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640071C1_20171226 | 32302 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175978U1_20171225 | 32303 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639397C1_20171221 | 32304 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638845C1_20171218 | 32305 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637734C1_20171206 | 32306 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174264U1_20171009 | 32307 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174187U1_20171006 | 32308 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630928C1_20170914 | 32309 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172608U1_20170714 | 32310 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172380U1_20170706 | 32311 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171207U1_20170524 | 32312 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2673057C2_20181122 | 32313 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2669994C2_20181017 | 32314 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2664184C2_20180815 | 32315 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658351C1_20180620 | 32316 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656142C1_20180531 | 32317 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2655343C1_20180525 | 32318 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654318C1_20180517 | 32319 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651389C1_20180419 | 32320 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651171C1_20180418 | 32321 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU178699U1_20180417 | 32322 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650460C1_20180413 | 32323 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649356C1_20180402 | 32324 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646706C1_20180306 | 32325 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644456C1_20180212 | 32326 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU176766U1_20180129 | 32327 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641553C1_20180118 | 32328 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639392C1_20171221 | 32329 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175719U1_20171215 | 32330 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636468C1_20171123 | 32331 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635534C1_20171113 | 32332 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634545C1_20171031 | 32333 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170302U1_20170419 | 32334 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2702668C1_20191009 | 32335 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2694146C2_20190709 | 32336 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2674700C2_20181212 | 32337 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2667987C2_20180925 | 32338 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU182822U1_20180904 | 32339 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2665041C2_20180827 | 32340 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2657220C1_20180608 | 32341 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656286C1_20180604 | 32342 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2653369C1_20180508 | 32343 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649425C1_20180403 | 32344 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649164C1_20180330 | 32345 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646790C1_20180307 | 32346 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2642485C1_20180125 | 32347 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640402C1_20180109 | 32348 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU176018U1_20171226 | 32349 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2639253C1_20171220 | 32350 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175306U1_20171129 | 32351 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635495C1_20171113 | 32352 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2631548C1_20170925 | 32353 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172609U1_20170714 | 32354 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172562U1_20170712 | 32355 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172013U1_20170626 | 32356 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171311U1_20170529 | 32357 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170338U1_20170421 | 32358 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170244U1_20170418 | 32359 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2689631C2_20190528 | 32360 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2669026C2_20181005 | 32361 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2656404C1_20180605 | 32362 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654940C1_20180523 | 32363 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2652732C1_20180428 | 32364 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649280C1_20180330 | 32365 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2647433C1_20180315 | 32366 from 32489
# For link https://yandex.ru/patents/doc/RU2643940C1_20180206
# + Link parsed https://yandex.ru/patents/doc/RU176638U1_20180124 | 32368 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636902C1_20171128 | 32369 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174746U1_20171031 | 32370 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634167C1_20171024 | 32371 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174423U1_20171012 | 32372 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2631115C1_20170919 | 32373 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2631056C1_20170918 | 32374 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172707U1_20170721 | 32375 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171589U1_20170606 | 32376 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171417U1_20170530 | 32377 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171362U1_20170529 | 32378 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171069U1_20170518 | 32379 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2671477C2_20181031 | 32380 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2666256C2_20180906 | 32381 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2663799C2_20180809 | 32382 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654317C1_20180517 | 32383 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU179185U1_20180503 | 32384 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650038C1_20180406 | 32385 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649643C1_20180404 | 32386 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649075C1_20180329 | 32387 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648142C1_20180322 | 32388 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646990C1_20180313 | 32389 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643110C1_20180130 | 32390 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2642685C1_20180125 | 32391 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638698C1_20171215 | 32392 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2636903C1_20171128 | 32393 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175253U1_20171128 | 32394 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174570U1_20171020 | 32395 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174436U1_20171012 | 32396 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174272U1_20171009 | 32397 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174283U1_20171009 | 32398 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173703U1_20170906 | 32399 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173622U1_20170904 | 32400 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173020U1_20170807 | 32401 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171436U1_20170531 | 32402 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171270U1_20170529 | 32403 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170041U1_20170412 | 32404 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2682954C1_20190322 | 32405 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2672581C2_20181116 | 32406 from 32489
# For link https://yandex.ru/patents/doc/RU2665966C2_20180905
# + Link parsed https://yandex.ru/patents/doc/RU2662365C2_20180725 | 32408 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2660341C2_20180705 | 32409 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2658444C1_20180621 | 32410 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2657555C1_20180614 | 32411 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU178737U1_20180418 | 32412 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646478C1_20180305 | 32413 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644395C1_20180212 | 32414 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643173C1_20180131 | 32415 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2642442C1_20180125 | 32416 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637802C1_20171207 | 32417 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637503C1_20171205 | 32418 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637506C1_20171205 | 32419 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175079U1_20171117 | 32420 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2635535C1_20171113 | 32421 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174473U1_20171016 | 32422 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633476C1_20171012 | 32423 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173809U1_20170912 | 32424 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170299U1_20170419 | 32425 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170243U1_20170418 | 32426 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170253U1_20170418 | 32427 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2689076C2_20190523 | 32428 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2684529C2_20190409 | 32429 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2651355C1_20180419 | 32430 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650408C1_20180411 | 32431 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650103C1_20180409 | 32432 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649170C1_20180330 | 32433 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648988C1_20180329 | 32434 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649066C1_20180329 | 32435 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648472C1_20180326 | 32436 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648497C1_20180326 | 32437 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU178029U1_20180321 | 32438 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640887C1_20180112 | 32439 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640888C1_20180112 | 32440 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2640213C1_20171227 | 32441 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175675U1_20171214 | 32442 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2637978C1_20171208 | 32443 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630237C1_20170906 | 32444 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2630246C1_20170906 | 32445 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173345U1_20170822 | 32446 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172910U1_20170731 | 32447 from 32489
# For link https://yandex.ru/patents/doc/RU170325U1_20170421
# + Link parsed https://yandex.ru/patents/doc/RU170300U1_20170419 | 32449 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2685947C2_20190423 | 32450 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2684529C9_20190417 | 32451 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2676767C2_20190111 | 32452 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2667100C2_20180914 | 32453 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2654939C1_20180523 | 32454 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650050C1_20180406 | 32455 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2649037C1_20180329 | 32456 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU177803U1_20180313 | 32457 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2643723C1_20180205 | 32458 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638424C1_20171213 | 32459 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2638304C1_20171213 | 32460 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174893U1_20171109 | 32461 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2634011C1_20171023 | 32462 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU174236U1_20171009 | 32463 from 32489
# For link https://yandex.ru/patents/doc/RU2632625C1_20171006
# + Link parsed https://yandex.ru/patents/doc/RU173013U1_20170804 | 32465 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172569U1_20170713 | 32466 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170301U1_20170419 | 32467 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU170226U1_20170418 | 32468 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2704495C1_20191029 | 32469 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2666900C2_20180913 | 32470 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2659164C1_20180628 | 32471 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650726C1_20180417 | 32472 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650582C1_20180416 | 32473 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2650002C1_20180406 | 32474 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2648444C1_20180326 | 32475 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646763C1_20180307 | 32476 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2646116C1_20180301 | 32477 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2645200C1_20180216 | 32478 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2644332C1_20180208 | 32479 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2641377C1_20180117 | 32480 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU176208U1_20180112 | 32481 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU175620U1_20171212 | 32482 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU2633778C1_20171018 | 32483 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173478U1_20170829 | 32484 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173368U1_20170823 | 32485 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU173189U1_20170815 | 32486 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU172145U1_20170629 | 32487 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171363U1_20170529 | 32488 from 32489
# + Link parsed https://yandex.ru/patents/doc/RU171166U1_20170523 | 32489 from 32489
